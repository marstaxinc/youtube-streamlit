# %%
# !pip install --upgrade streamlit
# Out:
# Requirement already satisfied: streamlit in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (1.5.0)
# Requirement already satisfied: cachetools>=4.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (5.0.0)
# Requirement already satisfied: gitpython!=3.1.19 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (3.1.26)
# Requirement already satisfied: pympler>=0.9 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: watchdog in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: python-dateutil in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: astor in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (0.8.1)
# Requirement already satisfied: tornado>=5.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (6.1)
# Requirement already satisfied: packaging in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (21.3)
# Requirement already satisfied: blinker in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (1.4)
# Requirement already satisfied: pandas>=0.21.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (1.3.5)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (3.19.4)
# Requirement already satisfied: click>=7.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (8.0.3)
# Requirement already satisfied: attrs in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (21.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: base58 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (2.1.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: validators in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: numpy in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (1.22.0)
# Requirement already satisfied: altair>=3.2.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: tzlocal in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (4.1)
# Requirement already satisfied: requests in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: toml in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: pyarrow in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from streamlit) (7.0.0)
# Requirement already satisfied: jinja2 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (3.0.3)
# Requirement already satisfied: entrypoints in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: toolz in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: pytz>=2017.3 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pandas>=0.21.0->streamlit) (2021.3)
# Requirement already satisfied: ipykernel>=5.1.2 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (6.8.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.2 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: six>=1.5 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from packaging->streamlit) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from requests->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from requests->streamlit) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from requests->streamlit) (2.0.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from requests->streamlit) (1.26.8)
# Requirement already satisfied: pytz-deprecation-shim in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from tzlocal->streamlit) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from validators->streamlit) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (8.0.1)
# Requirement already satisfied: nest-asyncio in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.4)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.1.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.18.1)
# Requirement already satisfied: tzdata in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal->streamlit) (2021.5)
# Requirement already satisfied: pickleshare in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: stack-data in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.4)
# Requirement already satisfied: setuptools>=18.5 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (56.0.0)
# Requirement already satisfied: pygments in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: backcall in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.24)
# Requirement already satisfied: black in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (21.12b0)
# Requirement already satisfied: jupyter-core>=4.6.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.3.0)
# Requirement already satisfied: notebook>=4.4.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.1)
# Requirement already satisfied: nbconvert in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.1)
# Requirement already satisfied: prometheus-client in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.1)
# Requirement already satisfied: argon2-cffi in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from black->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.2.3)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from black->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.0.1)
# Requirement already satisfied: platformdirs>=2 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from black->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.4.1)
# Requirement already satisfied: pathspec<1,>=0.9.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from black->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from black->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.4.3)
# Requirement already satisfied: asttokens in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: executing in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.2)
# Requirement already satisfied: pure-eval in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: bleach in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.1.0)
# Requirement already satisfied: defusedxml in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: testpath in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.10)
# Requirement already satisfied: cffi>=1.0.1 in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: webencodings in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: pycparser in /mnt/c/Users/marst/avilen/envs/.py396/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)

# %%
import streamlit as st
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3618/4143231958.py in <module>
# ----> 1 import streamlit as st
#       2 import numpy as np
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
df = pd.DataFrame({
    '1列目': [1, 2, 3, 4],
    '2列目': [10, 20, 30, 40]
})
df
# Out:
#    1列目  2列目
# 0    1   10
# 1    2   20
# 2    3   30
# 3    4   40

# %%
df.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_6963a_row3_col0, #T_6963a_row3_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_6963a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1列目</th>
#       <th class="col_heading level0 col1" >2列目</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6963a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6963a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_6963a_row0_col1" class="data row0 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6963a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6963a_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_6963a_row1_col1" class="data row1 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6963a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6963a_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6963a_row2_col1" class="data row2 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_6963a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6963a_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_6963a_row3_col1" class="data row3 col1" >40</td>
#     </tr>
#   </tbody>
# </table>

# %%
df = pd.DataFrame(
    np.random.randn(20, 15),
    columns=('col %d' % i for i in range(15)))
df
# Out:
#        col 0     col 1     col 2     col 3     col 4     col 5     col 6  \
# 0  -1.107173 -1.997854 -0.509304  0.571632  0.710212 -2.558040 -0.259869
# 1  -0.300168 -0.038672  0.444414 -1.823278  0.036052 -0.942696  0.785657
# 2   1.681432 -1.266811  1.091772 -1.049174 -0.286161 -0.031692  0.373032
# 3   0.309769  0.855528 -1.022633 -0.125619  1.112010 -0.606216  0.161244
# 4   0.759169  0.227025 -0.262897 -1.429418  1.068753 -1.216721  0.575723
# 5  -0.415083  0.428745  2.017447 -0.419036  1.237184 -0.986920 -0.166316
# 6   0.505142 -0.275411  0.892809 -0.367578 -0.544864  0.800961  0.075078
# 7  -1.499052 -0.480610  0.190080 -1.856873  2.114396  0.799606  0.165540
# 8   0.386304  0.231223  0.198724 -0.268825  0.695944  1.888979 -0.099156
# 9   0.350750  0.616290  1.096815  0.683572 -0.170845 -0.858175 -0.727188
# 10  0.488776  0.259825  0.929210 -0.508128 -0.201544  1.036447  1.201820
# 11 -0.250131  0.585839 -0.887777 -0.510182  1.342080 -0.052959  0.491235
# 12  0.409664  1.023520  1.475263 -0.101412  0.038024 -0.980899 -1.038533
# 13 -0.875799  0.693295 -0.294608  1.003115  0.272644 -1.802001  1.585497
# 14 -0.258272  0.015319  1.228158 -0.202252 -0.109887 -0.168384  0.719910
# 15 -1.510099 -2.150946  1.224925 -0.188095  0.134250 -0.868474  0.822312
# 16 -0.814886 -0.194057 -1.125293 -0.397136 -0.725058  1.119125 -1.607707
# 17  0.796618 -0.258687 -0.124955 -1.526938 -0.499857  0.653077  1.308853
# 18  1.079911 -0.040403 -0.345624  0.660260 -0.940814  1.945195 -1.389560
# 19 -0.260102 -1.347321 -0.157794  0.601537 -1.273488  0.065358  0.683127
#
#        col 7     col 8     col 9    col 10    col 11    col 12    col 13  \
# 0   0.648310 -1.139406  2.119691  0.029065  0.903247  1.052174  0.051911
# 1   0.556997 -0.349442 -0.702609 -1.261978  0.028782 -1.038899  0.872287
# 2   1.801841 -0.563177 -0.620698  0.846535 -0.243531  0.139055 -2.441169
# 3   0.532518  1.785538 -0.304510  0.030858 -0.472503 -0.216618 -0.055194
# 4  -0.467531 -0.295951 -1.081702 -0.604447  0.424695  0.091836 -0.578615
# 5   1.131119 -0.585782 -0.624409  1.796609 -0.401413 -1.394409 -1.156119
# 6   1.732259 -0.208615  0.651176 -1.158187  0.581809 -1.221191  1.441180
# 7  -2.052645  0.065542  0.289859 -1.400018  1.483961 -0.128593  0.192426
# 8   0.374461 -1.107982 -0.505595  1.635385 -0.177289 -1.575100 -0.438783
# 9  -0.086894 -1.412411  1.178130  0.612071  0.936497 -0.839599  1.423548
# 10  0.741124  0.368671 -0.010951  0.495223 -0.658088  1.735400 -1.788620
# 11  1.047452 -0.410669  0.082448  0.520776  0.928144 -0.998409 -1.466619
# 12  1.615576 -0.264197  0.274787  0.185036 -0.804185 -0.639603 -0.765187
# 13  1.723653 -0.777620 -0.536961 -0.475904 -1.199403  1.937220  0.338834
# 14  1.205132 -0.007198  0.267402 -0.784894 -1.199601 -0.816152 -0.673917
# 15 -0.601574 -0.259098  0.441305 -0.133482 -0.743511 -1.324387  0.247697
# 16 -0.104438  0.249867  0.849179  0.514006 -1.281447 -0.313960 -0.695374
# 17 -0.990969  0.859316 -0.184364 -0.944459  1.075594  1.550833  1.899666
# 18 -0.022070 -1.678531  0.856516  0.349620  0.182724  1.900493 -1.317657
# 19  0.090053  1.783119  1.609304  0.361048 -0.684829  0.129583  0.966477
#
#       col 14
# 0  -1.840722
# 1  -0.342471
# 2  -1.628176
# 3   0.106600
# 4   0.326373
# 5   0.218041
# 6  -0.873851
# 7  -0.611954
# 8  -1.761724
# 9  -0.143110
# 10  0.140138
# 11  0.639136
# 12 -1.599654
# 13  0.936190
# 14 -0.257339
# 15 -0.323197
# 16  0.659964
# 17  1.916015
# 18  0.319851
# 19 -0.854906

# %%
df = pd.DataFrame(
    np.random.rand(100, 2)/[50, 50]+[35.69, 139.70],
    columns=['lat', 'lon']
)
df
# Out:
#           lat         lon
# 0   35.702901  139.708511
# 1   35.694006  139.705425
# 2   35.708001  139.714252
# 3   35.702941  139.718917
# 4   35.709750  139.706000
# ..        ...         ...
# 95  35.706244  139.713939
# 96  35.699744  139.711976
# 97  35.707238  139.709605
# 98  35.701544  139.711897
# 99  35.694881  139.704891
#
# [100 rows x 2 columns]

# %%
st.line_chart(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3618/1269064901.py in <module>
# ----> 1 st.line_chart(df)
#
# NameError: name 'st' is not defined
